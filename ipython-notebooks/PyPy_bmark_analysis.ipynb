# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from jitlog_analyze import get_loops, get_all_loops
# Out:
# Warning: IOStream has no fileno.

# %%
all_loops = get_all_loops()
# Out:
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full-ldopt...
# 383160 symbols found
# 0%..loaded
# 0%..
# loading symbols from /opt/alttools/x86_64-centos6/bin/pypy...
# loaded
# 0%..
# 0 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /opt/alttools/x86_64-centos6/bin/pypy...
# loaded
# 0%..
# 0 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# loaded
# 0%..63%..loaded
# 26 symbols found
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# 0%..51%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..87%..loaded
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# 0%..82%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..58%..loaded
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# 0%..51%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy-cross/pypy/goal/pypy-jit-arm-nofp-full...
# 383110 symbols found
# loaded
# 0%..
# loading symbols from /work/bits0/bi45/vc/hg-misc/pypy/pypy/goal/pypy-ref...
# 26 symbols found
# loaded

# %%
all_loops["arm"].keys()
# Out:
# ['eparse',
#  'twisted_iteration',
#  'ai',
#  'raytrace-simple',
#  'float',
#  'crypto_pyaes',
#  'bm_mdp',
#  'go',
#  'html5lib',
#  'pidigits',
#  'deltablue',
#  'chaos',
#  'sympy_str',
#  'twisted_names',
#  'twisted_tcp',
#  'slowspitfire',
#  'sympy_expand',
#  'pyflate-fast',
#  'telco',
#  'meteor-contest',
#  'sympy_sum',
#  'nbody_modified',
#  'twisted_pb',
#  'spectral-norm',
#  'sympy_integrate',
#  'spitfire',
#  'richards',
#  'hexiom2',
#  'fannkuch',
#  'json_bench',
#  'django',
#  'bm_chameleon',
#  'spitfire_cstringio',
#  'bm_mako']

# %%
def hit_vs_len( loops ):
    arr = []
    for l in loops:
        arr.append( (l.count, len( l.operations ) ) )
    return arr

# %%
ai_arm_loops = all_loops["arm"]["ai"][1]
ai_arm_hvl = pd.DataFrame( hit_vs_len( ai_arm_loops ), columns=["hit","len"] )
ai_arm_hvl
# Out:
#        hit  len
# 0      110    1
# 1      110   22
# 2      178   17
# 3   121054    1
# 4   121054  107
# 5   966616   71
# 6   121220    1
# 7   242064   89
# 8   121020   66
# 9   120792   74
# 10  845539   74
# 11  120652   39
# 12  120651   98
# 13  120592   42
# 14     780  231
# 15     139  309
# 16    6434    1
# 17    6434  107
# 18   49602   71
# 19     548   20
# 20     548  115
# 21  119300  103
# 22  119809   28
# 23  119809  161
# 24   86058  149
# 25   59702  164
# 26   59704  164
# 27  119212  336
# 28    6020   39
# 29    6019   98
# 30    5920   95
# 31      32   27

# %%
ai_arm_hvl.plot(kind="scatter", y="hit", x="len")

# %%
def plot_hit_vs_len( bmark, ax=None ):
    loops = all_loops["arm"][bmark][1]
    hvl = pd.DataFrame( hit_vs_len( loops ), columns=["hit","len"] )
    hvl.plot( kind="scatter", y="hit", x="len", xlim=(0,None), ylim=(0,None), title=bmark, ax=ax, sharex=False )

# %%
ncols = 2
bmarks = sorted( all_loops["arm"].keys() )
nrows = (len(bmarks) + ncols - 1) / ncols
fig, axes = plt.subplots( nrows=nrows, ncols=ncols, figsize=(6*ncols,6*nrows) )
for i, bmark in enumerate(bmarks):
    plot_hit_vs_len( bmark, ax=axes[i/ncols,i%ncols] )
#for bmark in sorted( all_loops["arm"].keys() ):
#    plot_hit_vs_len( bmark )

# %%
def get_asm_nlines( asm ):
    if asm is None or asm.isspace() or asm == "":
        return 0
    return asm.count( "\n" ) + 1

def op_type_hist( loops ):
    hist_dict = {}
    static_ops = 0
    dyn_ops = 0
    for l in loops:
        for o in l.operations:
            if o.name == "debug_merge_point":
                continue
            if o.name not in hist_dict:
                s, d = 0, 0
            else:
                s, d = hist_dict[ o.name ]
            hist_dict[ o.name ] = s + 1, d + l.count
            static_ops += 1
            dyn_ops += l.count
    return hist_dict, static_ops, dyn_ops

def asm_hist( loops, asm_dict={} ):
    static_ops = 0
    prev_asm_nlines = 0

    for l in loops:
        try:
            l.force_asm()
        except AttributeError:
            print "WARNING: no force_asm, skipping"
            
        # assign and normalize for the missing nlines
        zero_cnt = 0
        for i,o in reversed( list( enumerate( l.operations ) ) ):
            if o.name == "debug_merge_point":
              continue
            o.asm_nlines = get_asm_nlines( o.asm )
            if o.asm_nlines == 0:
                zero_cnt += 1
                #print "zero at idx", i
            elif zero_cnt:
                #print "nonzero at idx {} value {}".format( i, o.asm_nlines )
                new_asm_nlines = float( o.asm_nlines ) / (zero_cnt + 1)
                for j in xrange( i, i + zero_cnt + 1 ):
                    #print "unzeroing at idx {} to value {}".format( j, new_asm_nlines )
                    l.operations[j].asm_nlines = new_asm_nlines
                zero_cnt = 0

        for o in l.operations:
            if o.name == "debug_merge_point":
                continue
            prev_asm_nlines = get_asm_nlines( o.asm )
            # 
            s, a = asm_dict.get( o.name, (0, 0) )
            asm_dict[ o.name ] = s + 1, a + o.asm_nlines
            static_ops += 1
    return asm_dict, static_ops

# %%
op_type_hist( all_loops["arm"]["ai"][1] )
# Out:
# ({'arraylen_gc': (29, 8934506),
#   'call': (24, 2438028),
#   'call_assembler': (10, 485153),
#   'call_may_force': (14, 777317),
#   'cond_call': (26, 5651044),
#   'finish': (10, 607853),
#   'force_token': (29, 3374567),
#   'getarrayitem_gc': (107, 11281477),
#   'getarrayitem_gc_pure': (9, 2478771),
#   'getfield_gc': (410, 44862820),
#   'getfield_gc_pure': (75, 10707842),
#   'getfield_raw': (14, 2680463),
#   'guard_class': (58, 7268586),
#   'guard_false': (149, 15636446),
#   'guard_isnull': (20, 1832355),
#   'guard_no_exception': (40, 4272465),
#   'guard_no_overflow': (23, 2248062),
#   'guard_nonnull': (20, 4291580),
#   'guard_nonnull_class': (75, 7361064),
#   'guard_not_forced': (24, 1262470),
#   'guard_not_invalidated': (24, 3046742),
#   'guard_true': (31, 3483905),
#   'guard_value': (94, 8914754),
#   'instance_ptr_eq': (10, 445831),
#   'int_add': (39, 6741334),
#   'int_add_ovf': (7, 1414466),
#   'int_eq': (8, 451766),
#   'int_ge': (13, 1596662),
#   'int_gt': (23, 1627203),
#   'int_is_true': (11, 1104510),
#   'int_is_zero': (16, 1905614),
#   'int_lt': (51, 7652415),
#   'int_sub': (17, 1342910),
#   'int_sub_ovf': (16, 833596),
#   'jump': (10, 2441947),
#   'keepalive': (1, 119212),
#   'label': (24, 3295234),
#   'new': (12, 690523),
#   'new_array': (4, 325218),
#   'new_array_clear': (25, 858604),
#   'new_with_vtable': (62, 6133871),
#   'ptr_eq': (2, 288),
#   'ptr_ne': (11, 1104510),
#   'same_as': (2, 127488),
#   'setarrayitem_gc': (188, 19006186),
#   'setfield_gc': (524, 51862453),
#   'uint_ge': (37, 5060603)},
#  2428,
#  270040714)

# %%
asm_hist( all_loops["arm"]["ai"][1] )
# Out:
# backend: arm
# backend: arm
# zero at idx 16
# nonzero at idx 15 value 2
# unzeroing at idx 15 to value 1.0
# unzeroing at idx 16 to value 1.0
# zero at idx 9
# nonzero at idx 8 value 2
# unzeroing at idx 8 to value 1.0
# unzeroing at idx 9 to value 1.0
# zero at idx 5
# nonzero at idx 4 value 2
# unzeroing at idx 4 to value 1.0
# unzeroing at idx 5 to value 1.0
# backend: arm
# zero at idx 11
# nonzero at idx 10 value 3
# unzeroing at idx 10 to value 1.5
# unzeroing at idx 11 to value 1.5
# zero at idx 7
# nonzero at idx 6 value 3
# unzeroing at idx 6 to value 1.5
# unzeroing at idx 7 to value 1.5
# zero at idx 4
# nonzero at idx 3 value 3
# unzeroing at idx 3 to value 1.5
# unzeroing at idx 4 to value 1.5
# backend: arm
# backend: arm
# zero at idx 105
# nonzero at idx 104 value 3
# unzeroing at idx 104 to value 1.5
# unzeroing at idx 105 to value 1.5
# zero at idx 100
# nonzero at idx 99 value 32
# unzeroing at idx 99 to value 16.0
# unzeroing at idx 100 to value 16.0
# zero at idx 84
# nonzero at idx 83 value 2
# unzeroing at idx 83 to value 1.0
# unzeroing at idx 84 to value 1.0
# zero at idx 74
# zero at idx 73
# nonzero at idx 72 value 33
# unzeroing at idx 72 to value 11.0
# unzeroing at idx 73 to value 11.0
# unzeroing at idx 74 to value 11.0
# zero at idx 56
# nonzero at idx 55 value 2
# unzeroing at idx 55 to value 1.0
# unzeroing at idx 56 to value 1.0
# zero at idx 54
# nonzero at idx 53 value 2
# unzeroing at idx 53 to value 1.0
# unzeroing at idx 54 to value 1.0
# zero at idx 42
# nonzero at idx 41 value 2
# unzeroing at idx 41 to value 1.0
# unzeroing at idx 42 to value 1.0
# zero at idx 33
# nonzero at idx 32 value 2
# unzeroing at idx 32 to value 1.0
# unzeroing at idx 33 to value 1.0
# zero at idx 17
# nonzero at idx 16 value 2
# unzeroing at idx 16 to value 1.0
# unzeroing at idx 17 to value 1.0
# zero at idx 10
# nonzero at idx 9 value 2
# unzeroing at idx 9 to value 1.0
# unzeroing at idx 10 to value 1.0
# backend: arm
# zero at idx 69
# zero at idx 68
# nonzero at idx 67 value 3
# unzeroing at idx 67 to value 1.0
# unzeroing at idx 68 to value 1.0
# unzeroing at idx 69 to value 1.0
# zero at idx 63
# nonzero at idx 62 value 32
# unzeroing at idx 62 to value 16.0
# unzeroing at idx 63 to value 16.0
# zero at idx 54
# nonzero at idx 53 value 2
# unzeroing at idx 53 to value 1.0
# unzeroing at idx 54 to value 1.0
# zero at idx 44
# zero at idx 43
# nonzero at idx 42 value 34
# unzeroing at idx 42 to value 11.3333333333
# unzeroing at idx 43 to value 11.3333333333
# unzeroing at idx 44 to value 11.3333333333
# zero at idx 27
# nonzero at idx 26 value 2
# unzeroing at idx 26 to value 1.0
# unzeroing at idx 27 to value 1.0
# zero at idx 25
# nonzero at idx 24 value 2
# unzeroing at idx 24 to value 1.0
# unzeroing at idx 25 to value 1.0
# zero at idx 13
# nonzero at idx 12 value 2
# unzeroing at idx 12 to value 1.0
# unzeroing at idx 13 to value 1.0
# backend: arm
# backend: arm
# zero at idx 65
# zero at idx 64
# nonzero at idx 63 value 33
# unzeroing at idx 63 to value 11.0
# unzeroing at idx 64 to value 11.0
# unzeroing at idx 65 to value 11.0
# zero at idx 44
# nonzero at idx 43 value 2
# unzeroing at idx 43 to value 1.0
# unzeroing at idx 44 to value 1.0
# zero at idx 17
# nonzero at idx 16 value 2
# unzeroing at idx 16 to value 1.0
# unzeroing at idx 17 to value 1.0
# zero at idx 10
# nonzero at idx 9 value 2
# unzeroing at idx 9 to value 1.0
# unzeroing at idx 10 to value 1.0
# backend: arm
# zero at idx 57
# nonzero at idx 56 value 2
# unzeroing at idx 56 to value 1.0
# unzeroing at idx 57 to value 1.0
# zero at idx 42
# nonzero at idx 41 value 2
# unzeroing at idx 41 to value 1.0
# unzeroing at idx 42 to value 1.0
# zero at idx 39
# nonzero at idx 38 value 2
# unzeroing at idx 38 to value 1.0
# unzeroing at idx 39 to value 1.0
# zero at idx 27
# nonzero at idx 26 value 2
# unzeroing at idx 26 to value 1.0
# unzeroing at idx 27 to value 1.0
# zero at idx 18
# nonzero at idx 17 value 2
# unzeroing at idx 17 to value 1.0
# unzeroing at idx 18 to value 1.0
# backend: arm
# zero at idx 55
# nonzero at idx 54 value 2
# unzeroing at idx 54 to value 1.0
# unzeroing at idx 55 to value 1.0
# zero at idx 45
# nonzero at idx 44 value 2
# unzeroing at idx 44 to value 1.0
# unzeroing at idx 45 to value 1.0
# zero at idx 8
# nonzero at idx 7 value 32
# unzeroing at idx 7 to value 16.0
# unzeroing at idx 8 to value 16.0
# backend: arm
# zero at idx 72
# zero at idx 71
# nonzero at idx 70 value 1
# unzeroing at idx 70 to value 0.333333333333
# unzeroing at idx 71 to value 0.333333333333
# unzeroing at idx 72 to value 0.333333333333
# zero at idx 55
# zero at idx 54
# nonzero at idx 53 value 33
# unzeroing at idx 53 to value 11.0
# unzeroing at idx 54 to value 11.0
# unzeroing at idx 55 to value 11.0
# zero at idx 36
# nonzero at idx 35 value 2
# unzeroing at idx 35 to value 1.0
# unzeroing at idx 36 to value 1.0
# zero at idx 24
# nonzero at idx 23 value 2
# unzeroing at idx 23 to value 1.0
# unzeroing at idx 24 to value 1.0
# zero at idx 9
# nonzero at idx 8 value 2
# unzeroing at idx 8 to value 1.0
# unzeroing at idx 9 to value 1.0
# backend: arm
# zero at idx 30
# nonzero at idx 29 value 2
# unzeroing at idx 29 to value 1.0
# unzeroing at idx 30 to value 1.0
# zero at idx 6
# nonzero at idx 5 value 1
# unzeroing at idx 5 to value 0.5
# unzeroing at idx 6 to value 0.5
# backend: arm
# zero at idx 96
# zero at idx 95
# nonzero at idx 94 value 2
# unzeroing at idx 94 to value 0.666666666667
# unzeroing at idx 95 to value 0.666666666667
# unzeroing at idx 96 to value 0.666666666667
# zero at idx 83
# nonzero at idx 82 value 31
# unzeroing at idx 82 to value 15.5
# unzeroing at idx 83 to value 15.5
# zero at idx 68
# nonzero at idx 67 value 2
# unzeroing at idx 67 to value 1.0
# unzeroing at idx 68 to value 1.0
# zero at idx 60
# nonzero at idx 59 value 2
# unzeroing at idx 59 to value 1.0
# unzeroing at idx 60 to value 1.0
# zero at idx 50
# zero at idx 49
# nonzero at idx 48 value 33
# unzeroing at idx 48 to value 11.0
# unzeroing at idx 49 to value 11.0
# unzeroing at idx 50 to value 11.0
# zero at idx 31
# nonzero at idx 30 value 2
# unzeroing at idx 30 to value 1.0
# unzeroing at idx 31 to value 1.0
# zero at idx 29
# nonzero at idx 28 value 2
# unzeroing at idx 28 to value 1.0
# unzeroing at idx 29 to value 1.0
# backend: arm
# zero at idx 33
# nonzero at idx 32 value 2
# unzeroing at idx 32 to value 1.0
# unzeroing at idx 33 to value 1.0
# zero at idx 9
# nonzero at idx 8 value 1
# unzeroing at idx 8 to value 0.5
# unzeroing at idx 9 to value 0.5
# zero at idx 2
# nonzero at idx 1 value 2
# unzeroing at idx 1 to value 1.0
# unzeroing at idx 2 to value 1.0
# backend: arm
# zero at idx 216
# nonzero at idx 215 value 11
# unzeroing at idx 215 to value 5.5
# unzeroing at idx 216 to value 5.5
# zero at idx 213
# nonzero at idx 212 value 12
# unzeroing at idx 212 to value 6.0
# unzeroing at idx 213 to value 6.0
# zero at idx 199
# nonzero at idx 198 value 36
# unzeroing at idx 198 to value 18.0
# unzeroing at idx 199 to value 18.0
# zero at idx 192
# nonzero at idx 191 value 55
# unzeroing at idx 191 to value 27.5
# unzeroing at idx 192 to value 27.5
# zero at idx 189
# zero at idx 188
# nonzero at idx 187 value 152
# unzeroing at idx 187 to value 50.6666666667
# unzeroing at idx 188 to value 50.6666666667
# unzeroing at idx 189 to value 50.6666666667
# zero at idx 159
# zero at idx 158
# nonzero at idx 157 value 23
# unzeroing at idx 157 to value 7.66666666667
# unzeroing at idx 158 to value 7.66666666667
# unzeroing at idx 159 to value 7.66666666667
# zero at idx 156
# zero at idx 155
# zero at idx 154
# zero at idx 153
# zero at idx 152
# nonzero at idx 151 value 67
# unzeroing at idx 151 to value 11.1666666667
# unzeroing at idx 152 to value 11.1666666667
# unzeroing at idx 153 to value 11.1666666667
# unzeroing at idx 154 to value 11.1666666667
# unzeroing at idx 155 to value 11.1666666667
# unzeroing at idx 156 to value 11.1666666667
# zero at idx 143
# nonzero at idx 142 value 53
# unzeroing at idx 142 to value 26.5
# unzeroing at idx 143 to value 26.5
# zero at idx 139
# nonzero at idx 138 value 2
# unzeroing at idx 138 to value 1.0
# unzeroing at idx 139 to value 1.0
# zero at idx 137
# nonzero at idx 136 value 2
# unzeroing at idx 136 to value 1.0
# unzeroing at idx 137 to value 1.0
# zero at idx 135
# nonzero at idx 134 value 2
# unzeroing at idx 134 to value 1.0
# unzeroing at idx 135 to value 1.0
# zero at idx 132
# nonzero at idx 131 value 5
# unzeroing at idx 131 to value 2.5
# unzeroing at idx 132 to value 2.5
# zero at idx 103
# nonzero at idx 102 value 2
# unzeroing at idx 102 to value 1.0
# unzeroing at idx 103 to value 1.0
# zero at idx 96
# nonzero at idx 95 value 2
# unzeroing at idx 95 to value 1.0
# unzeroing at idx 96 to value 1.0
# zero at idx 93
# nonzero at idx 92 value 2
# unzeroing at idx 92 to value 1.0
# unzeroing at idx 93 to value 1.0
# zero at idx 86
# nonzero at idx 85 value 2
# unzeroing at idx 85 to value 1.0
# unzeroing at idx 86 to value 1.0
# zero at idx 74
# nonzero at idx 73 value 2
# unzeroing at idx 73 to value 1.0
# unzeroing at idx 74 to value 1.0
# zero at idx 63
# nonzero at idx 62 value 2
# unzeroing at idx 62 to value 1.0
# unzeroing at idx 63 to value 1.0
# zero at idx 56
# nonzero at idx 55 value 2
# unzeroing at idx 55 to value 1.0
# unzeroing at idx 56 to value 1.0
# zero at idx 41
# nonzero at idx 40 value 2
# unzeroing at idx 40 to value 1.0
# unzeroing at idx 41 to value 1.0
# zero at idx 35
# nonzero at idx 34 value 2
# unzeroing at idx 34 to value 1.0
# unzeroing at idx 35 to value 1.0
# backend: arm
# zero at idx 294
# nonzero at idx 293 value 11
# unzeroing at idx 293 to value 5.5
# unzeroing at idx 294 to value 5.5
# zero at idx 291
# nonzero at idx 290 value 12
# unzeroing at idx 290 to value 6.0
# unzeroing at idx 291 to value 6.0
# zero at idx 277
# nonzero at idx 276 value 36
# unzeroing at idx 276 to value 18.0
# unzeroing at idx 277 to value 18.0
# zero at idx 270
# nonzero at idx 269 value 54
# unzeroing at idx 269 to value 27.0
# unzeroing at idx 270 to value 27.0
# zero at idx 267
# zero at idx 266
# nonzero at idx 265 value 152
# unzeroing at idx 265 to value 50.6666666667
# unzeroing at idx 266 to value 50.6666666667
# unzeroing at idx 267 to value 50.6666666667
# zero at idx 237
# zero at idx 236
# nonzero at idx 235 value 23
# unzeroing at idx 235 to value 7.66666666667
# unzeroing at idx 236 to value 7.66666666667
# unzeroing at idx 237 to value 7.66666666667
# zero at idx 234
# zero at idx 233
# zero at idx 232
# zero at idx 231
# zero at idx 230
# nonzero at idx 229 value 67
# unzeroing at idx 229 to value 11.1666666667
# unzeroing at idx 230 to value 11.1666666667
# unzeroing at idx 231 to value 11.1666666667
# unzeroing at idx 232 to value 11.1666666667
# unzeroing at idx 233 to value 11.1666666667
# unzeroing at idx 234 to value 11.1666666667
# zero at idx 221
# nonzero at idx 220 value 47
# unzeroing at idx 220 to value 23.5
# unzeroing at idx 221 to value 23.5
# zero at idx 217
# nonzero at idx 216 value 2
# unzeroing at idx 216 to value 1.0
# unzeroing at idx 217 to value 1.0
# zero at idx 215
# nonzero at idx 214 value 2
# unzeroing at idx 214 to value 1.0
# unzeroing at idx 215 to value 1.0
# zero at idx 213
# nonzero at idx 212 value 2
# unzeroing at idx 212 to value 1.0
# unzeroing at idx 213 to value 1.0
# zero at idx 210
# nonzero at idx 209 value 5
# unzeroing at idx 209 to value 2.5
# unzeroing at idx 210 to value 2.5
# zero at idx 182
# nonzero at idx 181 value 2
# unzeroing at idx 181 to value 1.0
# unzeroing at idx 182 to value 1.0
# zero at idx 175
# nonzero at idx 174 value 2
# unzeroing at idx 174 to value 1.0
# unzeroing at idx 175 to value 1.0
# zero at idx 172
# nonzero at idx 171 value 2
# unzeroing at idx 171 to value 1.0
# unzeroing at idx 172 to value 1.0
# zero at idx 165
# nonzero at idx 164 value 2
# unzeroing at idx 164 to value 1.0
# unzeroing at idx 165 to value 1.0
# zero at idx 154
# nonzero at idx 153 value 2
# unzeroing at idx 153 to value 1.0
# unzeroing at idx 154 to value 1.0
# zero at idx 143
# nonzero at idx 142 value 2
# unzeroing at idx 142 to value 1.0
# unzeroing at idx 143 to value 1.0
# zero at idx 138
# nonzero at idx 137 value 2
# unzeroing at idx 137 to value 1.0
# unzeroing at idx 138 to value 1.0
# zero at idx 129
# nonzero at idx 128 value 2
# unzeroing at idx 128 to value 1.0
# unzeroing at idx 129 to value 1.0
# zero at idx 123
# nonzero at idx 122 value 2
# unzeroing at idx 122 to value 1.0
# unzeroing at idx 123 to value 1.0
# zero at idx 116
# nonzero at idx 115 value 2
# unzeroing at idx 115 to value 1.0
# unzeroing at idx 116 to value 1.0
# zero at idx 109
# nonzero at idx 108 value 2
# unzeroing at idx 108 to value 1.0
# unzeroing at idx 109 to value 1.0
# zero at idx 99
# nonzero at idx 98 value 2
# unzeroing at idx 98 to value 1.0
# unzeroing at idx 99 to value 1.0
# zero at idx 88
# nonzero at idx 87 value 35
# unzeroing at idx 87 to value 17.5
# unzeroing at idx 88 to value 17.5
# zero at idx 86
# nonzero at idx 85 value 5
# unzeroing at idx 85 to value 2.5
# unzeroing at idx 86 to value 2.5
# zero at idx 84
# nonzero at idx 83 value 5
# unzeroing at idx 83 to value 2.5
# unzeroing at idx 84 to value 2.5
# zero at idx 67
# nonzero at idx 66 value 35
# unzeroing at idx 66 to value 17.5
# unzeroing at idx 67 to value 17.5
# zero at idx 65
# nonzero at idx 64 value 2
# unzeroing at idx 64 to value 1.0
# unzeroing at idx 65 to value 1.0
# zero at idx 61
# nonzero at idx 60 value 5
# unzeroing at idx 60 to value 2.5
# unzeroing at idx 61 to value 2.5
# zero at idx 55
# nonzero at idx 54 value 41
# unzeroing at idx 54 to value 20.5
# unzeroing at idx 55 to value 20.5
# zero at idx 47
# nonzero at idx 46 value 44
# unzeroing at idx 46 to value 22.0
# unzeroing at idx 47 to value 22.0
# zero at idx 43
# nonzero at idx 42 value 2
# unzeroing at idx 42 to value 1.0
# unzeroing at idx 43 to value 1.0
# zero at idx 41
# nonzero at idx 40 value 5
# unzeroing at idx 40 to value 2.5
# unzeroing at idx 41 to value 2.5
# zero at idx 35
# nonzero at idx 34 value 5
# unzeroing at idx 34 to value 2.5
# unzeroing at idx 35 to value 2.5
# zero at idx 25
# nonzero at idx 24 value 51
# unzeroing at idx 24 to value 25.5
# unzeroing at idx 25 to value 25.5
# zero at idx 21
# nonzero at idx 20 value 2
# unzeroing at idx 20 to value 1.0
# unzeroing at idx 21 to value 1.0
# zero at idx 18
# nonzero at idx 17 value 2
# unzeroing at idx 17 to value 1.0
# unzeroing at idx 18 to value 1.0
# zero at idx 16
# nonzero at idx 15 value 5
# unzeroing at idx 15 to value 2.5
# unzeroing at idx 16 to value 2.5
# zero at idx 10
# nonzero at idx 9 value 2
# unzeroing at idx 9 to value 1.0
# unzeroing at idx 10 to value 1.0
# zero at idx 7
# nonzero at idx 6 value 2
# unzeroing at idx 6 to value 1.0
# unzeroing at idx 7 to value 1.0
# backend: arm
# backend: arm
# zero at idx 105
# nonzero at idx 104 value 3
# unzeroing at idx 104 to value 1.5
# unzeroing at idx 105 to value 1.5
# zero at idx 100
# nonzero at idx 99 value 32
# unzeroing at idx 99 to value 16.0
# unzeroing at idx 100 to value 16.0
# zero at idx 84
# nonzero at idx 83 value 2
# unzeroing at idx 83 to value 1.0
# unzeroing at idx 84 to value 1.0
# zero at idx 74
# zero at idx 73
# nonzero at idx 72 value 33
# unzeroing at idx 72 to value 11.0
# unzeroing at idx 73 to value 11.0
# unzeroing at idx 74 to value 11.0
# zero at idx 56
# nonzero at idx 55 value 2
# unzeroing at idx 55 to value 1.0
# unzeroing at idx 56 to value 1.0
# zero at idx 54
# nonzero at idx 53 value 2
# unzeroing at idx 53 to value 1.0
# unzeroing at idx 54 to value 1.0
# zero at idx 42
# nonzero at idx 41 value 2
# unzeroing at idx 41 to value 1.0
# unzeroing at idx 42 to value 1.0
# zero at idx 33
# nonzero at idx 32 value 2
# unzeroing at idx 32 to value 1.0
# unzeroing at idx 33 to value 1.0
# zero at idx 17
# nonzero at idx 16 value 2
# unzeroing at idx 16 to value 1.0
# unzeroing at idx 17 to value 1.0
# zero at idx 10
# nonzero at idx 9 value 2
# unzeroing at idx 9 to value 1.0
# unzeroing at idx 10 to value 1.0
# backend: arm
# zero at idx 69
# zero at idx 68
# nonzero at idx 67 value 3
# unzeroing at idx 67 to value 1.0
# unzeroing at idx 68 to value 1.0
# unzeroing at idx 69 to value 1.0
# zero at idx 63
# nonzero at idx 62 value 32
# unzeroing at idx 62 to value 16.0
# unzeroing at idx 63 to value 16.0
# zero at idx 54
# nonzero at idx 53 value 2
# unzeroing at idx 53 to value 1.0
# unzeroing at idx 54 to value 1.0
# zero at idx 44
# zero at idx 43
# nonzero at idx 42 value 34
# unzeroing at idx 42 to value 11.3333333333
# unzeroing at idx 43 to value 11.3333333333
# unzeroing at idx 44 to value 11.3333333333
# zero at idx 27
# nonzero at idx 26 value 2
# unzeroing at idx 26 to value 1.0
# unzeroing at idx 27 to value 1.0
# zero at idx 25
# nonzero at idx 24 value 2
# unzeroing at idx 24 to value 1.0
# unzeroing at idx 25 to value 1.0
# zero at idx 13
# nonzero at idx 12 value 2
# unzeroing at idx 12 to value 1.0
# unzeroing at idx 13 to value 1.0
# backend: arm
# backend: arm
# zero at idx 112
# nonzero at idx 111 value 2
# unzeroing at idx 111 to value 1.0
# unzeroing at idx 112 to value 1.0
# zero at idx 103
# nonzero at idx 102 value 2
# unzeroing at idx 102 to value 1.0
# unzeroing at idx 103 to value 1.0
# zero at idx 97
# nonzero at idx 96 value 2
# unzeroing at idx 96 to value 1.0
# unzeroing at idx 97 to value 1.0
# zero at idx 89
# nonzero at idx 88 value 34
# unzeroing at idx 88 to value 17.0
# unzeroing at idx 89 to value 17.0
# zero at idx 83
# nonzero at idx 82 value 44
# unzeroing at idx 82 to value 22.0
# unzeroing at idx 83 to value 22.0
# zero at idx 81
# nonzero at idx 80 value 2
# unzeroing at idx 80 to value 1.0
# unzeroing at idx 81 to value 1.0
# zero at idx 77
# zero at idx 76
# nonzero at idx 75 value 140
# unzeroing at idx 75 to value 46.6666666667
# unzeroing at idx 76 to value 46.6666666667
# unzeroing at idx 77 to value 46.6666666667
# zero at idx 47
# zero at idx 46
# nonzero at idx 45 value 23
# unzeroing at idx 45 to value 7.66666666667
# unzeroing at idx 46 to value 7.66666666667
# unzeroing at idx 47 to value 7.66666666667
# zero at idx 44
# zero at idx 43
# zero at idx 42
# zero at idx 41
# zero at idx 40
# nonzero at idx 39 value 64
# unzeroing at idx 39 to value 10.6666666667
# unzeroing at idx 40 to value 10.6666666667
# unzeroing at idx 41 to value 10.6666666667
# unzeroing at idx 42 to value 10.6666666667
# unzeroing at idx 43 to value 10.6666666667
# unzeroing at idx 44 to value 10.6666666667
# zero at idx 11
# zero at idx 10
# nonzero at idx 9 value 148
# unzeroing at idx 9 to value 49.3333333333
# unzeroing at idx 10 to value 49.3333333333
# unzeroing at idx 11 to value 49.3333333333
# backend: arm
# zero at idx 100
# nonzero at idx 99 value 2
# unzeroing at idx 99 to value 1.0
# unzeroing at idx 100 to value 1.0
# zero at idx 91
# nonzero at idx 90 value 3
# unzeroing at idx 90 to value 1.5
# unzeroing at idx 91 to value 1.5
# zero at idx 86
# nonzero at idx 85 value 2
# unzeroing at idx 85 to value 1.0
# unzeroing at idx 86 to value 1.0
# zero at idx 78
# nonzero at idx 77 value 36
# unzeroing at idx 77 to value 18.0
# unzeroing at idx 78 to value 18.0
# zero at idx 72
# nonzero at idx 71 value 44
# unzeroing at idx 71 to value 22.0
# unzeroing at idx 72 to value 22.0
# zero at idx 70
# nonzero at idx 69 value 2
# unzeroing at idx 69 to value 1.0
# unzeroing at idx 70 to value 1.0
# zero at idx 66
# zero at idx 65
# nonzero at idx 64 value 142
# unzeroing at idx 64 to value 47.3333333333
# unzeroing at idx 65 to value 47.3333333333
# unzeroing at idx 66 to value 47.3333333333
# zero at idx 36
# zero at idx 35
# nonzero at idx 34 value 23
# unzeroing at idx 34 to value 7.66666666667
# unzeroing at idx 35 to value 7.66666666667
# unzeroing at idx 36 to value 7.66666666667
# zero at idx 33
# zero at idx 32
# zero at idx 31
# zero at idx 30
# zero at idx 29
# nonzero at idx 28 value 65
# unzeroing at idx 28 to value 10.8333333333
# unzeroing at idx 29 to value 10.8333333333
# unzeroing at idx 30 to value 10.8333333333
# unzeroing at idx 31 to value 10.8333333333
# unzeroing at idx 32 to value 10.8333333333
# unzeroing at idx 33 to value 10.8333333333
# zero at idx 6
# zero at idx 5
# nonzero at idx 4 value 138
# unzeroing at idx 4 to value 46.0
# unzeroing at idx 5 to value 46.0
# unzeroing at idx 6 to value 46.0
# backend: arm
# backend: arm
# zero at idx 158
# nonzero at idx 157 value 2
# unzeroing at idx 157 to value 1.0
# unzeroing at idx 158 to value 1.0
# zero at idx 151
# nonzero at idx 150 value 2
# unzeroing at idx 150 to value 1.0
# unzeroing at idx 151 to value 1.0
# zero at idx 142
# nonzero at idx 141 value 2
# unzeroing at idx 141 to value 1.0
# unzeroing at idx 142 to value 1.0
# zero at idx 131
# nonzero at idx 130 value 35
# unzeroing at idx 130 to value 17.5
# unzeroing at idx 131 to value 17.5
# zero at idx 129
# nonzero at idx 128 value 5
# unzeroing at idx 128 to value 2.5
# unzeroing at idx 129 to value 2.5
# zero at idx 127
# nonzero at idx 126 value 5
# unzeroing at idx 126 to value 2.5
# unzeroing at idx 127 to value 2.5
# zero at idx 110
# nonzero at idx 109 value 35
# unzeroing at idx 109 to value 17.5
# unzeroing at idx 110 to value 17.5
# zero at idx 108
# nonzero at idx 107 value 2
# unzeroing at idx 107 to value 1.0
# unzeroing at idx 108 to value 1.0
# zero at idx 104
# nonzero at idx 103 value 5
# unzeroing at idx 103 to value 2.5
# unzeroing at idx 104 to value 2.5
# zero at idx 98
# nonzero at idx 97 value 41
# unzeroing at idx 97 to value 20.5
# unzeroing at idx 98 to value 20.5
# zero at idx 90
# nonzero at idx 89 value 44
# unzeroing at idx 89 to value 22.0
# unzeroing at idx 90 to value 22.0
# zero at idx 86
# nonzero at idx 85 value 2
# unzeroing at idx 85 to value 1.0
# unzeroing at idx 86 to value 1.0
# zero at idx 84
# nonzero at idx 83 value 8
# unzeroing at idx 83 to value 4.0
# unzeroing at idx 84 to value 4.0
# zero at idx 70
# nonzero at idx 69 value 46
# unzeroing at idx 69 to value 23.0
# unzeroing at idx 70 to value 23.0
# zero at idx 66
# nonzero at idx 65 value 2
# unzeroing at idx 65 to value 1.0
# unzeroing at idx 66 to value 1.0
# zero at idx 63
# nonzero at idx 62 value 2
# unzeroing at idx 62 to value 1.0
# unzeroing at idx 63 to value 1.0
# zero at idx 61
# nonzero at idx 60 value 5
# unzeroing at idx 60 to value 2.5
# unzeroing at idx 61 to value 2.5
# zero at idx 47
# nonzero at idx 46 value 2
# unzeroing at idx 46 to value 1.0
# unzeroing at idx 47 to value 1.0
# zero at idx 36
# nonzero at idx 35 value 2
# unzeroing at idx 35 to value 1.0
# unzeroing at idx 36 to value 1.0
# zero at idx 29
# nonzero at idx 28 value 2
# unzeroing at idx 28 to value 1.0
# unzeroing at idx 29 to value 1.0
# zero at idx 14
# nonzero at idx 13 value 2
# unzeroing at idx 13 to value 1.0
# unzeroing at idx 14 to value 1.0
# zero at idx 8
# nonzero at idx 7 value 2
# unzeroing at idx 7 to value 1.0
# unzeroing at idx 8 to value 1.0
# backend: arm
# zero at idx 146
# nonzero at idx 145 value 2
# unzeroing at idx 145 to value 1.0
# unzeroing at idx 146 to value 1.0
# zero at idx 139
# nonzero at idx 138 value 2
# unzeroing at idx 138 to value 1.0
# unzeroing at idx 139 to value 1.0
# zero at idx 130
# nonzero at idx 129 value 3
# unzeroing at idx 129 to value 1.5
# unzeroing at idx 130 to value 1.5
# zero at idx 121
# nonzero at idx 120 value 35
# unzeroing at idx 120 to value 17.5
# unzeroing at idx 121 to value 17.5
# zero at idx 119
# nonzero at idx 118 value 5
# unzeroing at idx 118 to value 2.5
# unzeroing at idx 119 to value 2.5
# zero at idx 117
# nonzero at idx 116 value 5
# unzeroing at idx 116 to value 2.5
# unzeroing at idx 117 to value 2.5
# zero at idx 100
# nonzero at idx 99 value 35
# unzeroing at idx 99 to value 17.5
# unzeroing at idx 100 to value 17.5
# zero at idx 98
# nonzero at idx 97 value 2
# unzeroing at idx 97 to value 1.0
# unzeroing at idx 98 to value 1.0
# zero at idx 94
# nonzero at idx 93 value 5
# unzeroing at idx 93 to value 2.5
# unzeroing at idx 94 to value 2.5
# zero at idx 88
# nonzero at idx 87 value 41
# unzeroing at idx 87 to value 20.5
# unzeroing at idx 88 to value 20.5
# zero at idx 80
# nonzero at idx 79 value 45
# unzeroing at idx 79 to value 22.5
# unzeroing at idx 80 to value 22.5
# zero at idx 76
# nonzero at idx 75 value 2
# unzeroing at idx 75 to value 1.0
# unzeroing at idx 76 to value 1.0
# zero at idx 74
# nonzero at idx 73 value 8
# unzeroing at idx 73 to value 4.0
# unzeroing at idx 74 to value 4.0
# zero at idx 60
# nonzero at idx 59 value 50
# unzeroing at idx 59 to value 25.0
# unzeroing at idx 60 to value 25.0
# zero at idx 56
# nonzero at idx 55 value 2
# unzeroing at idx 55 to value 1.0
# unzeroing at idx 56 to value 1.0
# zero at idx 53
# nonzero at idx 52 value 2
# unzeroing at idx 52 to value 1.0
# unzeroing at idx 53 to value 1.0
# zero at idx 51
# nonzero at idx 50 value 5
# unzeroing at idx 50 to value 2.5
# unzeroing at idx 51 to value 2.5
# zero at idx 38
# nonzero at idx 37 value 2
# unzeroing at idx 37 to value 1.0
# unzeroing at idx 38 to value 1.0
# zero at idx 27
# nonzero at idx 26 value 2
# unzeroing at idx 26 to value 1.0
# unzeroing at idx 27 to value 1.0
# zero at idx 21
# nonzero at idx 20 value 2
# unzeroing at idx 20 to value 1.0
# unzeroing at idx 21 to value 1.0
# zero at idx 11
# nonzero at idx 10 value 2
# unzeroing at idx 10 to value 1.0
# unzeroing at idx 11 to value 1.0
# zero at idx 5
# nonzero at idx 4 value 2
# unzeroing at idx 4 to value 1.0
# unzeroing at idx 5 to value 1.0
# backend: arm
# zero at idx 149
# nonzero at idx 148 value 11
# unzeroing at idx 148 to value 5.5
# unzeroing at idx 149 to value 5.5
# zero at idx 146
# nonzero at idx 145 value 12
# unzeroing at idx 145 to value 6.0
# unzeroing at idx 146 to value 6.0
# zero at idx 132
# nonzero at idx 131 value 36
# unzeroing at idx 131 to value 18.0
# unzeroing at idx 132 to value 18.0
# zero at idx 125
# nonzero at idx 124 value 55
# unzeroing at idx 124 to value 27.5
# unzeroing at idx 125 to value 27.5
# zero at idx 122
# zero at idx 121
# nonzero at idx 120 value 152
# unzeroing at idx 120 to value 50.6666666667
# unzeroing at idx 121 to value 50.6666666667
# unzeroing at idx 122 to value 50.6666666667
# zero at idx 92
# zero at idx 91
# nonzero at idx 90 value 23
# unzeroing at idx 90 to value 7.66666666667
# unzeroing at idx 91 to value 7.66666666667
# unzeroing at idx 92 to value 7.66666666667
# zero at idx 89
# zero at idx 88
# zero at idx 87
# zero at idx 86
# zero at idx 85
# nonzero at idx 84 value 67
# unzeroing at idx 84 to value 11.1666666667
# unzeroing at idx 85 to value 11.1666666667
# unzeroing at idx 86 to value 11.1666666667
# unzeroing at idx 87 to value 11.1666666667
# unzeroing at idx 88 to value 11.1666666667
# unzeroing at idx 89 to value 11.1666666667
# zero at idx 76
# nonzero at idx 75 value 51
# unzeroing at idx 75 to value 25.5
# unzeroing at idx 76 to value 25.5
# zero at idx 72
# nonzero at idx 71 value 2
# unzeroing at idx 71 to value 1.0
# unzeroing at idx 72 to value 1.0
# zero at idx 70
# nonzero at idx 69 value 2
# unzeroing at idx 69 to value 1.0
# unzeroing at idx 70 to value 1.0
# zero at idx 68
# nonzero at idx 67 value 2
# unzeroing at idx 67 to value 1.0
# unzeroing at idx 68 to value 1.0
# zero at idx 65
# nonzero at idx 64 value 5
# unzeroing at idx 64 to value 2.5
# unzeroing at idx 65 to value 2.5
# zero at idx 36
# nonzero at idx 35 value 2
# unzeroing at idx 35 to value 1.0
# unzeroing at idx 36 to value 1.0
# zero at idx 29
# nonzero at idx 28 value 2
# unzeroing at idx 28 to value 1.0
# unzeroing at idx 29 to value 1.0
# zero at idx 26
# nonzero at idx 25 value 2
# unzeroing at idx 25 to value 1.0
# unzeroing at idx 26 to value 1.0
# zero at idx 19
# nonzero at idx 18 value 2
# unzeroing at idx 18 to value 1.0
# unzeroing at idx 19 to value 1.0
# zero at idx 10
# nonzero at idx 9 value 2
# unzeroing at idx 9 to value 1.0
# unzeroing at idx 10 to value 1.0
# backend: arm
# zero at idx 149
# nonzero at idx 148 value 11
# unzeroing at idx 148 to value 5.5
# unzeroing at idx 149 to value 5.5
# zero at idx 146
# nonzero at idx 145 value 12
# unzeroing at idx 145 to value 6.0
# unzeroing at idx 146 to value 6.0
# zero at idx 132
# nonzero at idx 131 value 36
# unzeroing at idx 131 to value 18.0
# unzeroing at idx 132 to value 18.0
# zero at idx 125
# nonzero at idx 124 value 55
# unzeroing at idx 124 to value 27.5
# unzeroing at idx 125 to value 27.5
# zero at idx 122
# zero at idx 121
# nonzero at idx 120 value 152
# unzeroing at idx 120 to value 50.6666666667
# unzeroing at idx 121 to value 50.6666666667
# unzeroing at idx 122 to value 50.6666666667
# zero at idx 92
# zero at idx 91
# nonzero at idx 90 value 23
# unzeroing at idx 90 to value 7.66666666667
# unzeroing at idx 91 to value 7.66666666667
# unzeroing at idx 92 to value 7.66666666667
# zero at idx 89
# zero at idx 88
# zero at idx 87
# zero at idx 86
# zero at idx 85
# nonzero at idx 84 value 67
# unzeroing at idx 84 to value 11.1666666667
# unzeroing at idx 85 to value 11.1666666667
# unzeroing at idx 86 to value 11.1666666667
# unzeroing at idx 87 to value 11.1666666667
# unzeroing at idx 88 to value 11.1666666667
# unzeroing at idx 89 to value 11.1666666667
# zero at idx 76
# nonzero at idx 75 value 51
# unzeroing at idx 75 to value 25.5
# unzeroing at idx 76 to value 25.5
# zero at idx 72
# nonzero at idx 71 value 2
# unzeroing at idx 71 to value 1.0
# unzeroing at idx 72 to value 1.0
# zero at idx 70
# nonzero at idx 69 value 2
# unzeroing at idx 69 to value 1.0
# unzeroing at idx 70 to value 1.0
# zero at idx 68
# nonzero at idx 67 value 2
# unzeroing at idx 67 to value 1.0
# unzeroing at idx 68 to value 1.0
# zero at idx 65
# nonzero at idx 64 value 5
# unzeroing at idx 64 to value 2.5
# unzeroing at idx 65 to value 2.5
# zero at idx 36
# nonzero at idx 35 value 2
# unzeroing at idx 35 to value 1.0
# unzeroing at idx 36 to value 1.0
# zero at idx 29
# nonzero at idx 28 value 2
# unzeroing at idx 28 to value 1.0
# unzeroing at idx 29 to value 1.0
# zero at idx 26
# nonzero at idx 25 value 2
# unzeroing at idx 25 to value 1.0
# unzeroing at idx 26 to value 1.0
# zero at idx 19
# nonzero at idx 18 value 2
# unzeroing at idx 18 to value 1.0
# unzeroing at idx 19 to value 1.0
# zero at idx 10
# nonzero at idx 9 value 2
# unzeroing at idx 9 to value 1.0
# unzeroing at idx 10 to value 1.0
# backend: arm
# zero at idx 323
# zero at idx 322
# zero at idx 321
# nonzero at idx 319 value 133
# unzeroing at idx 319 to value 33.25
# unzeroing at idx 320 to value 33.25
# unzeroing at idx 321 to value 33.25
# unzeroing at idx 322 to value 33.25
# zero at idx 317
# nonzero at idx 316 value 2
# unzeroing at idx 316 to value 1.0
# unzeroing at idx 317 to value 1.0
# zero at idx 308
# nonzero at idx 307 value 2
# unzeroing at idx 307 to value 1.0
# unzeroing at idx 308 to value 1.0
# zero at idx 292
# nonzero at idx 291 value 2
# unzeroing at idx 291 to value 1.0
# unzeroing at idx 292 to value 1.0
# zero at idx 267
# zero at idx 266
# nonzero at idx 265 value 37
# unzeroing at idx 265 to value 12.3333333333
# unzeroing at idx 266 to value 12.3333333333
# unzeroing at idx 267 to value 12.3333333333
# zero at idx 264
# nonzero at idx 263 value 2
# unzeroing at idx 263 to value 1.0
# unzeroing at idx 264 to value 1.0
# zero at idx 262
# nonzero at idx 261 value 5
# unzeroing at idx 261 to value 2.5
# unzeroing at idx 262 to value 2.5
# zero at idx 256
# nonzero at idx 255 value 2
# unzeroing at idx 255 to value 1.0
# unzeroing at idx 256 to value 1.0
# zero at idx 253
# nonzero at idx 252 value 5
# unzeroing at idx 252 to value 2.5
# unzeroing at idx 253 to value 2.5
# zero at idx 233
# nonzero at idx 232 value 38
# unzeroing at idx 232 to value 19.0
# unzeroing at idx 233 to value 19.0
# zero at idx 204
# nonzero at idx 203 value 44
# unzeroing at idx 203 to value 22.0
# unzeroing at idx 204 to value 22.0
# zero at idx 200
# nonzero at idx 199 value 11
# unzeroing at idx 199 to value 5.5
# unzeroing at idx 200 to value 5.5
# zero at idx 195
# nonzero at idx 194 value 8
# unzeroing at idx 194 to value 4.0
# unzeroing at idx 195 to value 4.0
# zero at idx 191
# nonzero at idx 190 value 8
# unzeroing at idx 190 to value 4.0
# unzeroing at idx 191 to value 4.0
# zero at idx 189
# zero at idx 188
# nonzero at idx 187 value 17
# unzeroing at idx 187 to value 5.66666666667
# unzeroing at idx 188 to value 5.66666666667
# unzeroing at idx 189 to value 5.66666666667
# zero at idx 183
# nonzero at idx 182 value 12
# unzeroing at idx 182 to value 6.0
# unzeroing at idx 183 to value 6.0
# zero at idx 179
# nonzero at idx 178 value 9
# unzeroing at idx 178 to value 4.5
# unzeroing at idx 179 to value 4.5
# zero at idx 175
# zero at idx 174
# nonzero at idx 173 value 35
# unzeroing at idx 173 to value 11.6666666667
# unzeroing at idx 174 to value 11.6666666667
# unzeroing at idx 175 to value 11.6666666667
# zero at idx 163
# nonzero at idx 162 value 2
# unzeroing at idx 162 to value 1.0
# unzeroing at idx 163 to value 1.0
# zero at idx 160
# nonzero at idx 159 value 2
# unzeroing at idx 159 to value 1.0
# unzeroing at idx 160 to value 1.0
# zero at idx 158
# nonzero at idx 157 value 6
# unzeroing at idx 157 to value 3.0
# unzeroing at idx 158 to value 3.0
# zero at idx 141
# nonzero at idx 140 value 2
# unzeroing at idx 140 to value 1.0
# unzeroing at idx 141 to value 1.0
# zero at idx 127
# nonzero at idx 126 value 2
# unzeroing at idx 126 to value 1.0
# unzeroing at idx 127 to value 1.0
# zero at idx 120
# nonzero at idx 119 value 2
# unzeroing at idx 119 to value 1.0
# unzeroing at idx 120 to value 1.0
# zero at idx 100
# nonzero at idx 99 value 2
# unzeroing at idx 99 to value 1.0
# unzeroing at idx 100 to value 1.0
# zero at idx 90
# zero at idx 89
# nonzero at idx 88 value 3
# unzeroing at idx 88 to value 1.0
# unzeroing at idx 89 to value 1.0
# unzeroing at idx 90 to value 1.0
# zero at idx 65
# nonzero at idx 64 value 2
# unzeroing at idx 64 to value 1.0
# unzeroing at idx 65 to value 1.0
# zero at idx 57
# nonzero at idx 56 value 2
# unzeroing at idx 56 to value 1.0
# unzeroing at idx 57 to value 1.0
# zero at idx 36
# nonzero at idx 35 value 2
# unzeroing at idx 35 to value 1.0
# unzeroing at idx 36 to value 1.0
# zero at idx 20
# nonzero at idx 19 value 2
# unzeroing at idx 19 to value 1.0
# unzeroing at idx 20 to value 1.0
# backend: arm
# zero at idx 30
# nonzero at idx 29 value 2
# unzeroing at idx 29 to value 1.0
# unzeroing at idx 30 to value 1.0
# zero at idx 6
# nonzero at idx 5 value 1
# unzeroing at idx 5 to value 0.5
# unzeroing at idx 6 to value 0.5
# backend: arm
# zero at idx 96
# zero at idx 95
# nonzero at idx 94 value 2
# unzeroing at idx 94 to value 0.666666666667
# unzeroing at idx 95 to value 0.666666666667
# unzeroing at idx 96 to value 0.666666666667
# zero at idx 83
# nonzero at idx 82 value 31
# unzeroing at idx 82 to value 15.5
# unzeroing at idx 83 to value 15.5
# zero at idx 68
# nonzero at idx 67 value 2
# unzeroing at idx 67 to value 1.0
# unzeroing at idx 68 to value 1.0
# zero at idx 60
# nonzero at idx 59 value 2
# unzeroing at idx 59 to value 1.0
# unzeroing at idx 60 to value 1.0
# zero at idx 50
# zero at idx 49
# nonzero at idx 48 value 33
# unzeroing at idx 48 to value 11.0
# unzeroing at idx 49 to value 11.0
# unzeroing at idx 50 to value 11.0
# zero at idx 31
# nonzero at idx 30 value 2
# unzeroing at idx 30 to value 1.0
# unzeroing at idx 31 to value 1.0
# zero at idx 29
# nonzero at idx 28 value 2
# unzeroing at idx 28 to value 1.0
# unzeroing at idx 29 to value 1.0
# backend: arm
# zero at idx 87
# nonzero at idx 86 value 2
# unzeroing at idx 86 to value 1.0
# unzeroing at idx 87 to value 1.0
# zero at idx 80
# nonzero at idx 79 value 3
# unzeroing at idx 79 to value 1.5
# unzeroing at idx 80 to value 1.5
# zero at idx 77
# nonzero at idx 76 value 2
# unzeroing at idx 76 to value 1.0
# unzeroing at idx 77 to value 1.0
# zero at idx 69
# nonzero at idx 68 value 36
# unzeroing at idx 68 to value 18.0
# unzeroing at idx 69 to value 18.0
# zero at idx 63
# nonzero at idx 62 value 44
# unzeroing at idx 62 to value 22.0
# unzeroing at idx 63 to value 22.0
# zero at idx 61
# nonzero at idx 60 value 2
# unzeroing at idx 60 to value 1.0
# unzeroing at idx 61 to value 1.0
# zero at idx 57
# zero at idx 56
# nonzero at idx 55 value 143
# unzeroing at idx 55 to value 47.6666666667
# unzeroing at idx 56 to value 47.6666666667
# unzeroing at idx 57 to value 47.6666666667
# zero at idx 27
# zero at idx 26
# nonzero at idx 25 value 23
# unzeroing at idx 25 to value 7.66666666667
# unzeroing at idx 26 to value 7.66666666667
# unzeroing at idx 27 to value 7.66666666667
# zero at idx 24
# zero at idx 23
# zero at idx 22
# zero at idx 21
# zero at idx 20
# nonzero at idx 19 value 64
# unzeroing at idx 19 to value 10.6666666667
# unzeroing at idx 20 to value 10.6666666667
# unzeroing at idx 21 to value 10.6666666667
# unzeroing at idx 22 to value 10.6666666667
# unzeroing at idx 23 to value 10.6666666667
# unzeroing at idx 24 to value 10.6666666667
# backend: arm
# ({'arraylen_gc': (29, 26.33333333333334),
#   'call': (24, 615),
#   'call_assembler': (10, 472.9166666666667),
#   'call_may_force': (14, 316.0),
#   'cond_call': (26, 489),
#   'finish': (10, 168),
#   'force_token': (29, 297.83333333333337),
#   'getarrayitem_gc': (107, 444.5),
#   'getarrayitem_gc_pure': (9, 27),
#   'getfield_gc': (410, 1140.5),
#   'getfield_gc_pure': (75, 127),
#   'getfield_raw': (14, 56),
#   'guard_class': (58, 358),
#   'guard_false': (149, 284.83333333333337),
#   'guard_isnull': (20, 37.0),
#   'guard_no_exception': (40, 240),
#   'guard_no_overflow': (23, 23.5),
#   'guard_nonnull': (20, 41),
#   'guard_nonnull_class': (75, 557),
#   'guard_not_forced': (24, 788.9166666666665),
#   'guard_not_invalidated': (24, 24),
#   'guard_true': (31, 48.0),
#   'guard_value': (94, 385.58333333333337),
#   'instance_ptr_eq': (10, 22.5),
#   'int_add': (39, 45),
#   'int_add_ovf': (7, 7.0),
#   'int_eq': (8, 9.0),
#   'int_ge': (13, 13.5),
#   'int_gt': (23, 40.0),
#   'int_is_true': (11, 11.0),
#   'int_is_zero': (16, 16.0),
#   'int_lt': (51, 138.16666666666666),
#   'int_sub': (17, 77.83333333333333),
#   'int_sub_ovf': (16, 16.5),
#   'jump': (10, 61),
#   'keepalive': (1, 0),
#   'label': (24, 206),
#   'new': (12, 122.5),
#   'new_array': (4, 80.5),
#   'new_array_clear': (25, 316.83333333333337),
#   'new_with_vtable': (62, 721.9999999999997),
#   'ptr_eq': (2, 2.5),
#   'ptr_ne': (11, 44),
#   'same_as': (2, 3.0),
#   'setarrayitem_gc': (188, 1843.1666666666665),
#   'setfield_gc': (524, 2518.166666666666),
#   'uint_ge': (37, 117.66666666666667)},
#  2428)

# %%
def plot_op_type_hist( hist_dict, bmark="?" ):
    df = pd.DataFrame( hist_dict.items(), columns=["op", "f"] )
    df['freq'], df['dyn_freq'] = zip( *df['f'] )
    del df['f']
    df = df.sort( columns="freq", ascending=False )
    #return df
    df.plot( kind='bar', x='op', y='freq', figsize=(14,6), title="static op frequency of " + bmark )
    df = df.sort( columns="dyn_freq", ascending=False )
    df.plot( kind='bar', x='op', y='dyn_freq', figsize=(14,6), title="dynamic op frequency of " + bmark )

    
def plot_asm_hist( asm_dict, bmark="?" ):
    df = pd.DataFrame( asm_dict.items(), columns=["op", "a"] )
    df["freq"], df["asm_cnt"] = zip( *df["a"] )
    df["avg_asm_cnt"] = df["asm_cnt"] / df["freq"]
    df = df.sort( columns="avg_asm_cnt", ascending=False )
    df.plot( kind='bar', x='op', y='avg_asm_cnt', figsize=(14,6), title="average asm/ir of " + bmark )
    
bmark = "ai"
hist_dict, _, _ = op_type_hist( all_loops["arm"][bmark][1] )
plot_op_type_hist( hist_dict, bmark=bmark )
asm_dict, _ = asm_hist( all_loops["arm"][bmark][1] )
plot_asm_hist( asm_dict, bmark=bmark )
# Out:
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm

# %%
def get_mean_op_type_hist():
    bmarks = sorted( all_loops["arm"].keys() )
    hist = {}
    for bmark in bmarks:
        loops = all_loops["arm"][bmark][1]
        hist_dict, static_ops, dynamic_ops = op_type_hist( loops )
        for op, (freq, dyn_freq) in hist_dict.items():
            if op not in hist:
                s, d = 0.0, 0.0
            else:
                s, d = hist[ op ]
            hist[op] = s + float( freq ) / static_ops / len(bmarks), \
                        d + float( dyn_freq ) / dynamic_ops / len(bmarks)
    return hist
hist = get_mean_op_type_hist()
plot_op_type_hist( hist, bmark="all" )

# %%
def categorize_hist( hist_dict ):
    cat = {"getfield_" : "memop",
           "setfield_" : "memop",
           "getarrayitem" : "memop",
           "setarrayitem" : "memop",
           "guard_"    : "guard",
           "int_"      : "int",
           "uint_"     : "int",
           "new"       : "new",
           "call"      : "call",
           "cond_call" : "call",
           "instance_ptr_eq" : "ptr",
           "ptr"       : "ptr",
           "unicode"   : "unicode",
           "str"       : "str",
           "copystr"   : "str",
           "copyunicode" : "unicode",
           "same_as"   : "int",
           "getinterior" : "memop",
           "setinterior" : "memop",
           "label"     : "ctrl",
           "jump"      : "ctrl",
           "finish"    : "ctrl",
           }
    new_hist_dict = {}
    for op, (sf, df) in hist_dict.items():
        for c_k, c_v in cat.items():
            if op.startswith( c_k ):
                op = c_v
                break
        if op in new_hist_dict:
            s, d = new_hist_dict[op]
        else:
            s, d = 0.0, 0.0
        new_hist_dict[op] = s + sf, d + df
    return new_hist_dict
plot_op_type_hist( categorize_hist( hist ), bmark="all" )

# %%
# average asm histogram
arm_asm_hist = {}
bmarks = sorted( all_loops["arm"].keys() )
for bmark in bmarks:
    loops = all_loops["arm"][bmark][1]
    asm_hist( loops, asm_dict=arm_asm_hist )

# plot
plot_asm_hist( arm_asm_hist, bmark="all" )
# Out:
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm
# backend: arm

# %%
# average asm histogram
x86_asm_hist = {}
bmarks = sorted( all_loops["x86"].keys() )
for bmark in bmarks:
    print "disasm:", bmark
    loops = all_loops["x86"][bmark][1]
    asm_hist( loops, asm_dict=x86_asm_hist )

# plot
plot_asm_hist( x86_asm_hist, bmark="all" )
# Out:
# disasm: ai
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: bm_chameleon
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: bm_mako
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: bm_mdp
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: chaos
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: crypto_pyaes
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: deltablue
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: django
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: eparse
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: fannkuch
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: float
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: go
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: hexiom2
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: html5lib
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: json_bench
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: meteor-contest
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: nbody_modified
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: pidigits
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: pyflate-fast
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# disasm: raytrace-simple
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: richards
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: slowspitfire
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: spectral-norm
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: spitfire
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: spitfire_cstringio
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: sympy_expand
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: sympy_integrate
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# ...
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: sympy_sum
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# WARNING: no force_asm, skipping
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: telco
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: twisted_iteration
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: twisted_names
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: twisted_pb
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# disasm: twisted_tcp
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64
# backend: x86_64

# %%
plot_asm_hist( arm_asm_hist, bmark="arm all" )
plot_asm_hist( x86_asm_hist, bmark="x86 all" )

# %%
def plot_asm_hist_arch( arm_dict, x86_dict, bmark="?" ):
    comb_dict = {}
    for op in arm_dict:
        comb_dict[op] = ( arm_dict[op], x86_dict[op] )
    df = pd.DataFrame( comb_dict.items(), columns=["op", "comb"] )
    df["arm"], df["x86"] = zip( *df["comb"] )
    df["arm_freq"], df["arm_asm_cnt"] = zip( *df["arm"] )
    df["arm_avg"] = df["arm_asm_cnt"] / df["arm_freq"]
    df["x86_freq"], df["x86_asm_cnt"] = zip( *df["x86"] )
    df["x86_avg"] = df["x86_asm_cnt"] / df["x86_freq"]
    df = df.sort( columns="arm_avg", ascending=False )
    df.plot( kind="bar", x="op", y=["arm_avg", "x86_avg"], figsize=(20,6), title="arm and x86 asm/ir" )
    return df
                                                  
    #df[arch + "freq"], df[arch + "asm_cnt"] = zip( *df[arch + "a"] )
    #df[arch + "avg_asm_cnt"] = df[arch + "asm_cnt"] / df[arch + "freq"]
    #df = df.sort( columns="avg_asm_cnt", ascending=False )
    #df.plot( kind='bar', x='op', y='avg_asm_cnt', figsize=(14,6), title="average asm/ir of " + bmark )
asm_df = plot_asm_hist_arch( arm_asm_hist, x86_asm_hist )

# %%
global_hist = get_mean_op_type_hist()
df2 = pd.DataFrame( global_hist.items(), columns=["op","f"] )
global_df = asm_df.merge( df2 )
global_df
# Out:
#                        op  arm_freq    arm_asm_cnt    arm_avg  x86_freq  \
# 0          call_assembler      1420   52601.666667  37.043427      1633
# 1               keepalive      1267   45212.000000  35.684294      1462
# 2                    jump      1842   58155.000000  31.571661      1946
# 3                    call      8591  234301.333333  27.272882      8714
# 4      copyunicodecontent        63    1657.500000  26.309524        60
# 5        call_release_gil       166    4272.500000  25.737952       160
# 6        guard_not_forced      5029  128482.916667  25.548403      4100
# 7          copystrcontent       156    3422.083333  21.936432       191
# 8               cond_call      1250   27048.000000  21.638400      1356
# 9          call_may_force      3443   71846.500000  20.867412      2307
# 10                 finish      1429   27366.000000  19.150455      1637
# 11             newunicode        70    1320.166667  18.859524        64
# 12        guard_exception        66    1192.000000  18.060606        74
# 13                 newstr       329    4676.569048  14.214496       396
# 14           int_floordiv        86    1205.000000  14.011628       101
# 15                  label      1728   23226.579365  13.441308      1878
# 16        new_array_clear      3761   49056.880051  13.043574      4316
# 17          uint_floordiv         4      52.000000  13.000000         2
# 18                    new      1093   12145.628752  11.112195      1186
# 19        new_with_vtable     12196  132330.850144  10.850348     13786
# 20    setinteriorfield_gc       160    1437.000000   8.981250       172
# 21                int_mod        28     226.000000   8.071429        48
# 22    guard_nonnull_class     20726  156894.591667   7.569941     21961
# 23              new_array        96     688.517857   7.172061        94
# 24         unicodesetitem        74     499.000000   6.743243        71
# 25            int_add_ovf       912    5901.166667   6.470577      1047
# 26            force_token     12596   80020.940260   6.352885     12608
# 27        setarrayitem_gc     15118   93026.221429   6.153342     17386
# 28            guard_class      8468   51292.150000   6.057174      9115
# 29     guard_no_exception     10712   63160.933333   5.896278      9712
# ..                    ...       ...            ...        ...       ...
# 49             strgetitem       285     621.000000   2.178947       397
# 50         unicodegetitem        75     162.000000   2.160000        62
# 51            int_mul_ovf       142     305.833333   2.153756       169
# 52       setarrayitem_raw       181     380.000000   2.099448       198
# 53                int_xor      1879    3908.150000   2.079910      1837
# 54                int_add      6679   13684.025000   2.048813      6985
# 55                 int_lt      7627   15460.113095   2.027024      8351
# 56                 int_eq      2076    4032.166667   1.942277      2374
# 57            arraylen_gc      3593    6830.333333   1.901011      4314
# 58                uint_lt        70     129.166667   1.845238       129
# 59                int_sub      1781    3172.033333   1.781041      1974
# 60                 int_gt      1182    2091.766667   1.769684      1165
# 61            guard_false     20890   36486.732143   1.746612     22055
# 62                 ptr_eq       231     387.500000   1.677489       368
# 63                 int_ge      4633    7562.538889   1.632320      5322
# 64             guard_true      8453   12833.491270   1.518217      9904
# 65                uint_ge      3003    4302.833333   1.432845      3360
# 66            int_is_true      2817    3988.583333   1.415898      3131
# 67       getfield_gc_pure     18143   25383.483333   1.399079     20615
# 68                 int_ne       897    1056.500000   1.177815      1164
# 69            int_sub_ovf       568     644.833333   1.135270       717
# 70             int_rshift       367     412.333333   1.123524       682
# 71                 int_le       218     234.166667   1.074159       270
# 72             int_lshift       125     133.000000   1.064000       280
# 73  guard_not_invalidated      5954    6113.083333   1.026719      5789
# 74                 int_or        23      23.000000   1.000000       102
# 75                int_neg         3       3.000000   1.000000         3
# 76            int_is_zero      1899    1874.269048   0.986977      2067
# 77             int_invert        24      19.000000   0.791667        51
# 78                same_as       170      59.285714   0.348739       223
#
#       x86_asm_cnt    x86_avg                                       f
# 0    27070.083333  16.576903    (0.00252387281299, 0.00118262105348)
# 1    23376.000000  15.989056   (0.00181285815335, 0.000968638148003)
# 2    25542.000000  13.125385    (0.00648144597621, 0.00927020987293)
# 3   101358.750000  11.631713      (0.0240828456491, 0.0309901733267)
# 4      774.500000  12.908333  (7.71205819381e-05, 0.000131874245343)
# 5     2116.000000  13.225000  (0.000418838706898, 0.000833494006307)
# 6    49361.416667  12.039370      (0.0135421493984, 0.0132022780671)
# 7     2107.785714  11.035527  (0.000404878967549, 0.000371698365232)
# 8    17153.000000  12.649705    (0.00405957012556, 0.00676967151807)
# 9    20414.000000   8.848721      (0.0105994378785, 0.0111861630073)
# 10   23568.000000  14.397068    (0.00422839196622, 0.00234098233605)
# 11     649.833333  10.153646  (0.000103583174092, 0.000212092327772)
# 12     595.500000   8.047297  (0.000191521930028, 0.000253763144052)
# 13    2554.344048   6.450364    (0.00131950114537, 0.00273398752498)
# 14     558.000000   5.524752  (0.000347335461014, 0.000683230569126)
# 15    8495.495238   4.523693      (0.00967924331589, 0.011284861983)
# 16   24972.873954   5.786115     (0.0054792170054, 0.00361654510756)
# 17       8.000000   4.000000    (5.768143696e-06, 1.01545433087e-07)
# 18    5826.543038   4.912768    (0.00239272767666, 0.00256265040914)
# 19   58029.990765   4.209342      (0.0257540324646, 0.0179902945625)
# 20     431.500000   2.508721  (0.000200347806191, 0.000185309460914)
# 21     212.000000   4.416667  (0.000221431360086, 0.000180231075532)
# 22   91874.677778   4.183538      (0.0522093264415, 0.0503117869379)
# 23     377.836905   4.019542  (0.000241283965181, 8.45543481656e-05)
# 24     134.500000   1.894366   (0.000205811678157, 0.00050474415215)
# 25    3788.083333   3.618036    (0.00339788321418, 0.00545806980406)
# 26   35602.718434   2.823820      (0.0293611468136, 0.0299276966679)
# 27   30758.390476   1.769147       (0.0282459785129, 0.021619048591)
# 28   18329.700000   2.010938      (0.0213727387465, 0.0224404156249)
# 29   29237.400000   3.010441      (0.0333604792227, 0.0433777192073)
# ..            ...        ...                                     ...
# 49     407.000000   1.025189  (0.000992357204705, 0.000641901874443)
# 50      67.500000   1.088710   (0.000180041634041, 0.00084091836744)
# 51     250.750000   1.483728  (0.000552941047966, 0.000840878814258)
# 52     204.500000   1.032828    (0.00118016504236, 0.00128764390655)
# 53    2325.138889   1.265726    (0.00222062504659, 0.00235332197759)
# 54    8742.611111   1.251627      (0.0145200530911, 0.0207031597064)
# 55   12840.203571   1.537565      (0.0215098823269, 0.0320083275626)
# 56    3224.000000   1.358045    (0.00509321025496, 0.00578641839074)
# 57    5917.666667   1.371735        (0.0083122632591, 0.01017214414)
# 58     200.166667   1.551680  (0.000114239245141, 3.33702460085e-05)
# 59    2955.083333   1.497003    (0.00253632547334, 0.00264999800115)
# 60    1423.050000   1.221502    (0.00360261207206, 0.00327630331309)
# 61   28503.063095   1.292363       (0.0528456409773, 0.056689516754)
# 62     409.500000   1.112772   (0.00101590564329, 0.000573718186569)
# 63    5765.938889   1.083416    (0.00863997812988, 0.00656685883771)
# 64   11110.524603   1.121822      (0.0221721221788, 0.0260091746484)
# 65    3617.000000   1.076488    (0.00792933337978, 0.00803419049272)
# 66    3671.666667   1.172682    (0.00598574505081, 0.00679418908884)
# 67   23626.305556   1.146074       (0.0406203665756, 0.039754684317)
# 68    1129.000000   0.969931    (0.00253395031115, 0.00258401580693)
# 69     825.000000   1.150628    (0.00135300569709, 0.00155283363165)
# 70     936.833333   1.373656     (0.00120930436099, 0.0023438404179)
# 71     273.400000   1.012593   (0.000645708730228, 0.00103892841088)
# 72     486.500000   1.737500   (0.000444018838076, 0.00116034835691)
# 73    6085.894444   1.051286      (0.0152107549625, 0.0166973619186)
# 74     104.000000   1.019608  (6.09804222246e-05, 4.44178056251e-05)
# 75       6.000000   2.000000  (1.08959365421e-05, 2.75868069894e-06)
# 76    1995.102381   0.965216      (0.0044994639182, 0.0047371157297)
# 77      51.000000   1.000000   (3.4608862176e-05, 1.05635883564e-06)
# 78      61.323810   0.274995  (0.000761946855901, 0.000919821296484)
#
# [79 rows x 8 columns]

# %%
global_df["stat_freq"], global_df["dyn_freq"] = zip( *global_df["f"] )
del global_df["f"]
global_df
# Out:
#                        op  arm_freq    arm_asm_cnt    arm_avg  x86_freq  \
# 0          call_assembler      1420   52601.666667  37.043427      1633
# 1               keepalive      1267   45212.000000  35.684294      1462
# 2                    jump      1842   58155.000000  31.571661      1946
# 3                    call      8591  234301.333333  27.272882      8714
# 4      copyunicodecontent        63    1657.500000  26.309524        60
# 5        call_release_gil       166    4272.500000  25.737952       160
# 6        guard_not_forced      5029  128482.916667  25.548403      4100
# 7          copystrcontent       156    3422.083333  21.936432       191
# 8               cond_call      1250   27048.000000  21.638400      1356
# 9          call_may_force      3443   71846.500000  20.867412      2307
# 10                 finish      1429   27366.000000  19.150455      1637
# 11             newunicode        70    1320.166667  18.859524        64
# 12        guard_exception        66    1192.000000  18.060606        74
# 13                 newstr       329    4676.569048  14.214496       396
# 14           int_floordiv        86    1205.000000  14.011628       101
# 15                  label      1728   23226.579365  13.441308      1878
# 16        new_array_clear      3761   49056.880051  13.043574      4316
# 17          uint_floordiv         4      52.000000  13.000000         2
# 18                    new      1093   12145.628752  11.112195      1186
# 19        new_with_vtable     12196  132330.850144  10.850348     13786
# 20    setinteriorfield_gc       160    1437.000000   8.981250       172
# 21                int_mod        28     226.000000   8.071429        48
# 22    guard_nonnull_class     20726  156894.591667   7.569941     21961
# 23              new_array        96     688.517857   7.172061        94
# 24         unicodesetitem        74     499.000000   6.743243        71
# 25            int_add_ovf       912    5901.166667   6.470577      1047
# 26            force_token     12596   80020.940260   6.352885     12608
# 27        setarrayitem_gc     15118   93026.221429   6.153342     17386
# 28            guard_class      8468   51292.150000   6.057174      9115
# 29     guard_no_exception     10712   63160.933333   5.896278      9712
# ..                    ...       ...            ...        ...       ...
# 49             strgetitem       285     621.000000   2.178947       397
# 50         unicodegetitem        75     162.000000   2.160000        62
# 51            int_mul_ovf       142     305.833333   2.153756       169
# 52       setarrayitem_raw       181     380.000000   2.099448       198
# 53                int_xor      1879    3908.150000   2.079910      1837
# 54                int_add      6679   13684.025000   2.048813      6985
# 55                 int_lt      7627   15460.113095   2.027024      8351
# 56                 int_eq      2076    4032.166667   1.942277      2374
# 57            arraylen_gc      3593    6830.333333   1.901011      4314
# 58                uint_lt        70     129.166667   1.845238       129
# 59                int_sub      1781    3172.033333   1.781041      1974
# 60                 int_gt      1182    2091.766667   1.769684      1165
# 61            guard_false     20890   36486.732143   1.746612     22055
# 62                 ptr_eq       231     387.500000   1.677489       368
# 63                 int_ge      4633    7562.538889   1.632320      5322
# 64             guard_true      8453   12833.491270   1.518217      9904
# 65                uint_ge      3003    4302.833333   1.432845      3360
# 66            int_is_true      2817    3988.583333   1.415898      3131
# 67       getfield_gc_pure     18143   25383.483333   1.399079     20615
# 68                 int_ne       897    1056.500000   1.177815      1164
# 69            int_sub_ovf       568     644.833333   1.135270       717
# 70             int_rshift       367     412.333333   1.123524       682
# 71                 int_le       218     234.166667   1.074159       270
# 72             int_lshift       125     133.000000   1.064000       280
# 73  guard_not_invalidated      5954    6113.083333   1.026719      5789
# 74                 int_or        23      23.000000   1.000000       102
# 75                int_neg         3       3.000000   1.000000         3
# 76            int_is_zero      1899    1874.269048   0.986977      2067
# 77             int_invert        24      19.000000   0.791667        51
# 78                same_as       170      59.285714   0.348739       223
#
#       x86_asm_cnt    x86_avg  stat_freq  dyn_freq
# 0    27070.083333  16.576903   0.002524  0.001183
# 1    23376.000000  15.989056   0.001813  0.000969
# 2    25542.000000  13.125385   0.006481  0.009270
# 3   101358.750000  11.631713   0.024083  0.030990
# 4      774.500000  12.908333   0.000077  0.000132
# 5     2116.000000  13.225000   0.000419  0.000833
# 6    49361.416667  12.039370   0.013542  0.013202
# 7     2107.785714  11.035527   0.000405  0.000372
# 8    17153.000000  12.649705   0.004060  0.006770
# 9    20414.000000   8.848721   0.010599  0.011186
# 10   23568.000000  14.397068   0.004228  0.002341
# 11     649.833333  10.153646   0.000104  0.000212
# 12     595.500000   8.047297   0.000192  0.000254
# 13    2554.344048   6.450364   0.001320  0.002734
# 14     558.000000   5.524752   0.000347  0.000683
# 15    8495.495238   4.523693   0.009679  0.011285
# 16   24972.873954   5.786115   0.005479  0.003617
# 17       8.000000   4.000000   0.000006  0.000000
# 18    5826.543038   4.912768   0.002393  0.002563
# 19   58029.990765   4.209342   0.025754  0.017990
# 20     431.500000   2.508721   0.000200  0.000185
# 21     212.000000   4.416667   0.000221  0.000180
# 22   91874.677778   4.183538   0.052209  0.050312
# 23     377.836905   4.019542   0.000241  0.000085
# 24     134.500000   1.894366   0.000206  0.000505
# 25    3788.083333   3.618036   0.003398  0.005458
# 26   35602.718434   2.823820   0.029361  0.029928
# 27   30758.390476   1.769147   0.028246  0.021619
# 28   18329.700000   2.010938   0.021373  0.022440
# 29   29237.400000   3.010441   0.033360  0.043378
# ..            ...        ...        ...       ...
# 49     407.000000   1.025189   0.000992  0.000642
# 50      67.500000   1.088710   0.000180  0.000841
# 51     250.750000   1.483728   0.000553  0.000841
# 52     204.500000   1.032828   0.001180  0.001288
# 53    2325.138889   1.265726   0.002221  0.002353
# 54    8742.611111   1.251627   0.014520  0.020703
# 55   12840.203571   1.537565   0.021510  0.032008
# 56    3224.000000   1.358045   0.005093  0.005786
# 57    5917.666667   1.371735   0.008312  0.010172
# 58     200.166667   1.551680   0.000114  0.000033
# 59    2955.083333   1.497003   0.002536  0.002650
# 60    1423.050000   1.221502   0.003603  0.003276
# 61   28503.063095   1.292363   0.052846  0.056690
# 62     409.500000   1.112772   0.001016  0.000574
# 63    5765.938889   1.083416   0.008640  0.006567
# 64   11110.524603   1.121822   0.022172  0.026009
# 65    3617.000000   1.076488   0.007929  0.008034
# 66    3671.666667   1.172682   0.005986  0.006794
# 67   23626.305556   1.146074   0.040620  0.039755
# 68    1129.000000   0.969931   0.002534  0.002584
# 69     825.000000   1.150628   0.001353  0.001553
# 70     936.833333   1.373656   0.001209  0.002344
# 71     273.400000   1.012593   0.000646  0.001039
# 72     486.500000   1.737500   0.000444  0.001160
# 73    6085.894444   1.051286   0.015211  0.016697
# 74     104.000000   1.019608   0.000061  0.000044
# 75       6.000000   2.000000   0.000011  0.000003
# 76    1995.102381   0.965216   0.004499  0.004737
# 77      51.000000   1.000000   0.000035  0.000001
# 78      61.323810   0.274995   0.000762  0.000920
#
# [79 rows x 9 columns]

# %%
global_df["wtd_arm_avg"] = global_df["arm_avg"] * global_df["dyn_freq"]
global_df = global_df.sort( "wtd_arm_avg", ascending=False )
#global_df = global_df.set_index( "op" )
#global_df
#global_df.plot( kind="bar", y=["wtd_arm_avg","arm_avg"], secondary_y="arm_avg", figsize=(20,6) )
global_df[["arm_avg","wtd_arm_avg"]].plot(kind="bar", secondary_y="arm_avg", figsize=(20,6))
#global_df.plot( kind="bar", y=["wtd_arm_avg","arm_avg"], secondary_y="arm_avg", figsize=(20,6) )
#global_df.arm_avg.plot( kind="bar", figsize=(20,6), style="g" )
#global_df.plot( kind="bar", secondary_y="arm_avg" )
#global_df.plot( kind="bar", x="op", y="arm_avg", secondary_y=True, figsize=(20,6) )
